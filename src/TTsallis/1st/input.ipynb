# %%
using DataFrames,CSV

# %%
df = CSV.read("../Trho_Maxwell1215.csv", DataFrame)

Ts = df.T
mus = df.mu_star

df_out = DataFrame(T=Ts, mu_star=mus)
CSV.write("first_q_1.001.csv.csv", df_out)
# Out:
# "first_q_1.001.csv.csv"
